# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# import imblearn
# from imblearn.over_sampling import SMOTE, ADASYN

# %%
# np.random.choice(np.arange(0,2),p=[0.92,0.08])

# %%
# reading the data

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# getting their shapes
print("Shape of train :", train.shape)
print("Shape of test :", test.shape)
# Out:
# Shape of train : (54808, 14)
# Shape of test : (23490, 13)

# %%
train.isnull().any()
# Out:
# employee_id             False
# department              False
# region                  False
# education                True
# gender                  False
# recruitment_channel     False
# no_of_trainings         False
# age                     False
# previous_year_rating     True
# length_of_service       False
# KPIs_met >80%           False
# awards_won              False
# avg_training_score      False
# is_promoted             False
# dtype: bool

# %% [markdown]
# Columns having Nan values:
#     1. education
#     2. previous_year_rating

# %% [markdown]
# Metrics in imputing Nan values for education:
#     1. department
#     2. region
#     3. recruitment_channel
#     4. is_promoted
#     5. gender

# %%
train['education'] =train['education'].fillna('missing')
test['education'] =test['education'].fillna('missing')

# %%
# missing value treatment

for dept in train['department'].unique():
    for region in train['region'].unique():
        for gender in train['gender'].unique():
            # for pro in train['is_promoted'].unique():
                for rec in train['recruitment_channel'].unique():
                    try:
                        df_slice = train[train['department']==dept][train['region']==region][train['gender']==gender][train['recruitment_channel']==rec]

                        null_indexes = list(df_slice[df_slice['education'].isna()==True].index)
                        mode_value = df_slice[df_slice['education'].isna()==False]['education'].mode()[0]

                        print (dept, region, gender,rec, mode_value)

                        for i in null_indexes:
                            train['education'].iloc[i] = mode_value


                    except:
                        pass

for dept in test['department'].unique():
    for region in test['region'].unique():
        for gender in test['gender'].unique():
            # for pro in train['is_promoted'].unique():
                for rec in train['recruitment_channel'].unique():
                    try:
                        df_slice = test[test['department']==dept][test['region']==region][test['gender']==gender][train['recruitment_channel']==rec]

                        null_indexes = list(df_slice[df_slice['education'].isna()==True].index)
                        mode_value = df_slice[df_slice['education'].isna()==False]['education'].mode()[0]

                        print (dept, region, gender,rec, mode_value)

                        for i in null_indexes:
                            test['education'].iloc[i] = mode_value


                    except:
                        pass
# Out:
# Sales & Marketing region_7 f sourcing Bachelor's
# Sales & Marketing region_7 f other Bachelor's
# Sales & Marketing region_7 m sourcing Bachelor's
# Sales & Marketing region_7 m other Bachelor's
# Sales & Marketing region_7 m referred Bachelor's
# Sales & Marketing region_22 f sourcing Bachelor's
# Sales & Marketing region_22 f other Bachelor's
# Sales & Marketing region_22 f referred Bachelor's
# Sales & Marketing region_22 m sourcing Bachelor's
# Sales & Marketing region_22 m other Bachelor's
# Sales & Marketing region_22 m referred Bachelor's
# Sales & Marketing region_19 f sourcing Bachelor's
# Sales & Marketing region_19 f other Bachelor's
# Sales & Marketing region_19 m sourcing Bachelor's
# Sales & Marketing region_19 m other Bachelor's
# Sales & Marketing region_23 f sourcing Bachelor's
# Sales & Marketing region_23 f other Master's & above
# Sales & Marketing region_23 m sourcing Bachelor's
# Sales & Marketing region_23 m other Bachelor's
# Sales & Marketing region_26 f sourcing Bachelor's
# Sales & Marketing region_26 f other Bachelor's
# Sales & Marketing region_26 m sourcing Bachelor's
# Sales & Marketing region_26 m other Bachelor's
# Technology region_21 m sourcing Bachelor's
# Technology region_21 m other Bachelor's
# Technology region_8 f sourcing Bachelor's
# Technology region_8 f other Bachelor's
# Technology region_8 m sourcing Bachelor's
# Technology region_8 m other Bachelor's
# Technology region_32 f sourcing Bachelor's
# Technology region_32 f other Bachelor's
# Technology region_32 m sourcing Bachelor's
# Technology region_32 m other Bachelor's
# Technology region_6 f sourcing Bachelor's
# Technology region_6 f other Bachelor's
# Technology region_6 m sourcing Bachelor's
# Technology region_6 m other Bachelor's
# Technology region_6 m referred Bachelor's
# Technology region_33 f sourcing Bachelor's
# Technology region_33 f other Bachelor's
# Technology region_33 m sourcing Bachelor's
# Technology region_33 m other Bachelor's
# Technology region_24 f sourcing Bachelor's
# Technology region_24 f other Bachelor's
# Technology region_24 m sourcing Bachelor's
# Technology region_24 m other Bachelor's
# Technology region_3 f sourcing Bachelor's
# Technology region_3 m sourcing Bachelor's
# Technology region_3 m other Bachelor's
# Technology region_9 f sourcing Bachelor's
# Technology region_9 f other Bachelor's
# Technology region_9 m sourcing Bachelor's
# Technology region_9 m other Bachelor's
# Analytics region_7 f sourcing Bachelor's
# Analytics region_7 f other Bachelor's
# Analytics region_7 m sourcing Bachelor's
# Analytics region_7 m other Bachelor's
# Analytics region_22 f sourcing Bachelor's
# Analytics region_22 f other Bachelor's
# Analytics region_22 f referred Bachelor's
# Analytics region_22 m sourcing Bachelor's
# Analytics region_22 m other Bachelor's
# Analytics region_22 m referred Bachelor's
# Analytics region_19 m sourcing Bachelor's
# Analytics region_19 m other Bachelor's
# Analytics region_23 m sourcing Bachelor's
# Analytics region_23 m other Bachelor's
# Analytics region_26 f sourcing Bachelor's
# Analytics region_26 f other Bachelor's
# Analytics region_26 m sourcing Bachelor's
# Analytics region_26 m other Bachelor's
# Analytics region_2 f sourcing Bachelor's
# Analytics region_2 f other Bachelor's
# Analytics region_2 m sourcing Bachelor's
# Analytics region_2 m other Bachelor's
# Analytics region_20 f sourcing Bachelor's
# Analytics region_20 f other Bachelor's
# Analytics region_20 m sourcing Bachelor's
# Analytics region_20 m other Bachelor's
# Analytics region_34 m sourcing Bachelor's
# Analytics region_34 m other Bachelor's
# Analytics region_1 m sourcing Bachelor's
# Analytics region_1 m other Bachelor's
# Analytics region_4 f sourcing Bachelor's
# Analytics region_4 f other Bachelor's
# Analytics region_4 m sourcing Bachelor's
# Analytics region_4 m other Bachelor's
# Analytics region_29 f sourcing Bachelor's
# Analytics region_29 f other Bachelor's
# Analytics region_29 m sourcing Bachelor's
# Analytics region_29 m other Bachelor's
# Analytics region_29 m referred Bachelor's
# Analytics region_31 f sourcing Bachelor's
# Analytics region_31 f other Bachelor's
# Analytics region_31 m sourcing Bachelor's
# Analytics region_31 m other Bachelor's
# Analytics region_15 f sourcing Bachelor's
# Analytics region_15 f other Bachelor's
# Analytics region_15 m sourcing Bachelor's
# Analytics region_15 m other Bachelor's
# Analytics region_14 m sourcing Bachelor's
# Analytics region_14 m other Bachelor's
# Analytics region_11 f sourcing Bachelor's
# Analytics region_11 f other Bachelor's
# Analytics region_11 m sourcing Bachelor's
# Analytics region_11 m other Bachelor's
# Analytics region_5 m sourcing Bachelor's
# Analytics region_5 m other Bachelor's
# Analytics region_28 f sourcing Bachelor's
# Analytics region_28 f other Bachelor's
# Analytics region_28 m sourcing Bachelor's
# Analytics region_28 m other Bachelor's
# Analytics region_17 m sourcing Bachelor's
# Analytics region_17 m other Bachelor's
# Analytics region_13 f sourcing Bachelor's
# Analytics region_13 f other Bachelor's
# Analytics region_13 m sourcing Bachelor's
# Analytics region_13 m other Bachelor's
# Analytics region_16 m sourcing Bachelor's
# Analytics region_16 m other Bachelor's
# Analytics region_25 f sourcing Bachelor's
# Analytics region_25 f other Bachelor's
# Analytics region_25 m sourcing Bachelor's
# Analytics region_25 m other Bachelor's
# Analytics region_10 m sourcing Master's & above
# Analytics region_10 m other Master's & above
# Analytics region_27 f other Bachelor's
# Analytics region_27 m sourcing Bachelor's
# Analytics region_27 m other Bachelor's
# Analytics region_30 m sourcing Bachelor's
# Analytics region_30 m other Bachelor's
# Analytics region_12 m sourcing Bachelor's
# Analytics region_12 m other Bachelor's
# Analytics region_21 f other Bachelor's
# Analytics region_21 m sourcing Bachelor's
# Analytics region_21 m other Bachelor's
# Analytics region_8 f other Bachelor's
# Analytics region_8 m sourcing Bachelor's
# Analytics region_8 m other Bachelor's
# Analytics region_32 f sourcing Bachelor's
# Analytics region_32 f other Bachelor's
# Analytics region_32 m sourcing Bachelor's
# Analytics region_32 m other Bachelor's
# Analytics region_6 f sourcing Bachelor's
# Analytics region_6 f other Bachelor's
# Analytics region_6 m sourcing Bachelor's
# Analytics region_6 m other Bachelor's
# Analytics region_33 m sourcing Bachelor's
# Analytics region_33 m other Bachelor's
# Analytics region_24 m sourcing Bachelor's
# Analytics region_24 m other Bachelor's
# Analytics region_3 m sourcing Bachelor's
# Analytics region_3 m other Bachelor's
# Analytics region_9 f other Master's & above
# Analytics region_9 m sourcing Bachelor's
# Analytics region_9 m other Bachelor's
# R&D region_7 f sourcing Bachelor's
# R&D region_7 f other Master's & above
# R&D region_7 m sourcing Master's & above
# R&D region_7 m other Master's & above
# R&D region_22 f sourcing Bachelor's
# R&D region_22 f other Bachelor's
# R&D region_22 m sourcing Bachelor's
# R&D region_22 m other Bachelor's
# R&D region_22 m referred Bachelor's
# R&D region_19 m sourcing Bachelor's
# R&D region_19 m other Bachelor's
# R&D region_23 m sourcing Master's & above
# R&D region_23 m other Master's & above
# R&D region_26 f sourcing Master's & above
# R&D region_26 m sourcing Bachelor's
# R&D region_26 m other Bachelor's
# R&D region_26 m referred Bachelor's
# R&D region_2 f sourcing Master's & above
# R&D region_2 f other Bachelor's
# R&D region_2 m sourcing Master's & above
# R&D region_2 m other Bachelor's
# R&D region_20 m sourcing Bachelor's
# R&D region_20 m other Bachelor's
# R&D region_4 f sourcing Master's & above
# R&D region_4 f other Master's & above
# R&D region_4 m sourcing Master's & above
# R&D region_4 m other Master's & above
# Procurement region_32 f sourcing Bachelor's
# Procurement region_32 m sourcing Bachelor's
# Procurement region_32 m other Bachelor's
# Procurement region_6 f sourcing Bachelor's
# Procurement region_6 f other Bachelor's
# Procurement region_6 m sourcing Bachelor's
# Procurement region_6 m other Bachelor's
# Procurement region_33 f sourcing Bachelor's
# Procurement region_33 f other Bachelor's
# Procurement region_33 m sourcing Bachelor's
# Procurement region_33 m other Bachelor's
# Procurement region_24 f sourcing Bachelor's
# Procurement region_24 f other Bachelor's
# Procurement region_24 m sourcing Bachelor's
# Procurement region_24 m other Bachelor's
# Procurement region_3 m sourcing Master's & above
# Procurement region_3 m other Bachelor's
# Procurement region_9 f sourcing Bachelor's
# Procurement region_9 f other Bachelor's
# Procurement region_9 m sourcing Bachelor's
# Procurement region_9 m other Bachelor's
# Finance region_7 f sourcing Bachelor's
# Finance region_7 f other Bachelor's
# Finance region_7 m sourcing Bachelor's
# Finance region_7 m other Bachelor's
# Finance region_22 f sourcing Bachelor's
# Finance region_22 f other Bachelor's
# Finance region_22 m sourcing Bachelor's
# Finance region_22 m other Bachelor's
# Finance region_19 f sourcing Bachelor's
# Finance region_19 m sourcing Bachelor's
# Finance region_19 m other Bachelor's
# Finance region_23 m sourcing Bachelor's
# Finance region_23 m other Master's & above
# Finance region_26 f sourcing Bachelor's
# Finance region_26 f other Bachelor's
# Finance region_26 m sourcing Bachelor's
# Finance region_26 m other Bachelor's
# Finance region_2 f sourcing Bachelor's
# Finance region_2 f other Bachelor's
# Finance region_2 m sourcing Bachelor's
# Finance region_2 m other Bachelor's
# Finance region_2 m referred Bachelor's
# Finance region_20 f sourcing Bachelor's
# Finance region_20 f other Master's & above
# Finance region_20 m sourcing Bachelor's
# Finance region_20 m other Bachelor's
# Finance region_34 m sourcing Bachelor's
# Finance region_34 m other Bachelor's
# Finance region_1 f sourcing Bachelor's
# Finance region_1 f other Bachelor's
# Finance region_1 m sourcing Bachelor's
# Finance region_1 m other Master's & above
# Finance region_4 f sourcing Bachelor's
# Finance region_4 f other Master's & above
# Finance region_4 m sourcing Bachelor's
# Finance region_4 m other Master's & above
# Finance region_29 f sourcing Bachelor's
# Finance region_29 f other Bachelor's
# Finance region_29 m sourcing Bachelor's
# Finance region_29 m other Bachelor's
# Finance region_31 f sourcing Bachelor's
# Finance region_31 f other Bachelor's
# Finance region_31 m sourcing Bachelor's
# Finance region_31 m other Bachelor's
# Finance region_15 f sourcing Bachelor's
# Finance region_15 f other Bachelor's
# Finance region_15 m sourcing Bachelor's
# Finance region_15 m other Bachelor's
# Finance region_14 f sourcing Bachelor's
# Finance region_14 f other Bachelor's
# Finance region_14 m sourcing Bachelor's
# Finance region_14 m other Bachelor's
# Finance region_11 f sourcing Bachelor's
# Finance region_11 f other Bachelor's
# Finance region_11 m sourcing Bachelor's
# Finance region_11 m other Bachelor's
# Finance region_5 m sourcing Bachelor's
# Finance region_5 m other Bachelor's
# Finance region_28 f sourcing Bachelor's
# Finance region_28 f other Bachelor's
# Finance region_28 m sourcing Master's & above
# Finance region_28 m other Master's & above
# Finance region_17 m other Bachelor's
# Finance region_13 f sourcing Bachelor's
# Finance region_13 f other Bachelor's
# Finance region_13 m sourcing Bachelor's
# Finance region_13 m other Bachelor's
# Finance region_16 f sourcing Bachelor's
# Finance region_16 f other Bachelor's
# Finance region_16 m sourcing Bachelor's
# Finance region_16 m other Bachelor's
# Finance region_25 m sourcing Bachelor's
# Finance region_25 m other Bachelor's
# Finance region_10 m sourcing Bachelor's
# Finance region_10 m other Master's & above
# Finance region_27 f sourcing Bachelor's
# Finance region_27 f other Bachelor's
# Finance region_27 m sourcing Bachelor's
# Finance region_27 m other Bachelor's
# Finance region_30 f sourcing Bachelor's
# Finance region_30 f other Bachelor's
# Finance region_30 m sourcing Bachelor's
# Finance region_30 m other Bachelor's
# Finance region_12 m sourcing Bachelor's
# Finance region_12 m other Bachelor's
# Finance region_21 f sourcing Bachelor's
# Finance region_21 m sourcing Bachelor's
# Finance region_21 m other Bachelor's
# Finance region_8 f other Bachelor's
# Finance region_8 m sourcing Bachelor's
# Finance region_8 m other Bachelor's
# Finance region_32 f sourcing Bachelor's
# Finance region_32 f other Bachelor's
# Finance region_32 m sourcing Bachelor's
# Finance region_32 m other Bachelor's
# Finance region_6 f sourcing Bachelor's
# Finance region_6 f other Bachelor's
# Finance region_6 m sourcing Bachelor's
# Finance region_6 m other Bachelor's
# Finance region_33 m other Master's & above
# Finance region_24 m sourcing Bachelor's
# Finance region_24 m other Bachelor's
# Finance region_3 f other Bachelor's
# Finance region_3 m sourcing Bachelor's
# Finance region_3 m other Bachelor's
# Finance region_9 m sourcing Bachelor's
# Finance region_9 m other Bachelor's
# HR region_7 f sourcing Bachelor's
# HR region_7 f other Bachelor's
# HR region_7 m sourcing Bachelor's
# HR region_7 m other Bachelor's
# HR region_22 f sourcing Bachelor's
# HR region_22 f other Bachelor's
# HR region_22 f referred Bachelor's
# HR region_22 m sourcing Bachelor's
# HR region_22 m other Bachelor's
# HR region_22 m referred Bachelor's
# HR region_19 m sourcing Bachelor's
# HR region_19 m other Bachelor's
# HR region_23 f sourcing Bachelor's
# HR region_23 f other Bachelor's
# HR region_23 m sourcing Bachelor's
# HR region_23 m other Bachelor's
# HR region_26 f sourcing Bachelor's
# HR region_26 f other Bachelor's
# HR region_26 m sourcing Bachelor's
# HR region_26 m other Bachelor's
# HR region_2 f sourcing Bachelor's
# HR region_2 f other Bachelor's
# HR region_2 f referred Bachelor's
# HR region_2 m sourcing Bachelor's
# HR region_2 m other Bachelor's
# HR region_2 m referred Bachelor's
# HR region_20 f sourcing Bachelor's
# HR region_20 f other Bachelor's
# HR region_20 m sourcing Bachelor's
# HR region_20 m other Bachelor's
# HR region_34 m sourcing Bachelor's
# HR region_34 m other Bachelor's
# HR region_1 f sourcing Bachelor's
# HR region_1 f other Bachelor's
# HR region_1 m sourcing Master's & above
# HR region_1 m other Master's & above
# HR region_4 f sourcing Master's & above
# HR region_4 f other Master's & above
# HR region_4 m sourcing Bachelor's
# Technology region_5 m other Bachelor's
# Technology region_5 f sourcing Bachelor's
# Technology region_5 f other Bachelor's
# Technology region_28 m sourcing Master's & above
# Technology region_28 m other Bachelor's
# Technology region_28 f sourcing Master's & above
# Technology region_28 f other Bachelor's
# Technology region_28 f referred Master's & above
# Technology region_15 m sourcing Bachelor's
# Technology region_15 m other Bachelor's
# Technology region_15 m referred Bachelor's
# Technology region_15 f sourcing Bachelor's
# Technology region_15 f other Bachelor's
# Technology region_3 m sourcing Bachelor's
# Technology region_3 m other Bachelor's
# Technology region_3 m referred Master's & above
# Technology region_3 f sourcing Bachelor's
# Technology region_25 m sourcing Master's & above
# Technology region_25 m other Bachelor's
# Technology region_25 f sourcing Bachelor's
# Technology region_25 f other Bachelor's
# Technology region_12 m sourcing Bachelor's
# Technology region_12 m other Bachelor's
# Technology region_12 f sourcing Bachelor's
# Technology region_12 f other Bachelor's
# Technology region_12 f referred Bachelor's
# Technology region_21 m sourcing Bachelor's
# Technology region_21 m other Bachelor's
# Technology region_21 m referred Bachelor's
# ...
# Analytics region_26 f sourcing Bachelor's
# Analytics region_26 f other Bachelor's
# Analytics region_4 m sourcing Bachelor's
# Analytics region_4 m other Bachelor's
# Analytics region_4 m referred Master's & above
# Analytics region_13 m sourcing Bachelor's
# Analytics region_13 m other Bachelor's
# Analytics region_13 f sourcing Bachelor's
# Analytics region_13 f other Bachelor's
# Analytics region_2 m sourcing Bachelor's
# Analytics region_2 m other Bachelor's
# Analytics region_2 m referred Bachelor's
# Analytics region_2 f sourcing Bachelor's
# Analytics region_2 f other Bachelor's
# Analytics region_29 m sourcing Bachelor's
# Analytics region_29 m other Bachelor's
# Analytics region_29 f sourcing Bachelor's
# Analytics region_29 f other Bachelor's
# Analytics region_7 m sourcing Bachelor's
# Analytics region_7 m other Bachelor's
# Analytics region_7 m referred Bachelor's
# Analytics region_7 f sourcing Bachelor's
# Analytics region_7 f other Bachelor's
# Analytics region_22 m sourcing Bachelor's
# Analytics region_22 m other Bachelor's
# Analytics region_22 m referred Bachelor's
# Analytics region_22 f sourcing Bachelor's
# Analytics region_22 f other Bachelor's
# Analytics region_16 m sourcing Bachelor's
# Analytics region_16 m other Bachelor's
# Analytics region_16 m referred Bachelor's
# Analytics region_17 m sourcing Bachelor's
# Analytics region_17 m other Bachelor's
# Analytics region_24 m sourcing Bachelor's
# Analytics region_24 m other Bachelor's
# Analytics region_24 m referred Master's & above
# Analytics region_11 m sourcing Bachelor's
# Analytics region_11 m other Bachelor's
# Analytics region_11 m referred Bachelor's
# Analytics region_27 m sourcing Bachelor's
# Analytics region_27 m other Bachelor's
# Analytics region_27 m referred Bachelor's
# Analytics region_27 f sourcing Bachelor's
# Analytics region_27 f other Bachelor's
# Analytics region_9 m sourcing Bachelor's
# Analytics region_9 m other Bachelor's
# Analytics region_9 m referred Bachelor's
# Analytics region_9 f other Master's & above
# Analytics region_20 m sourcing Bachelor's
# Analytics region_20 m other Bachelor's
# Analytics region_34 m sourcing Bachelor's
# Analytics region_34 m other Bachelor's
# Analytics region_23 m sourcing Bachelor's
# Analytics region_23 m other Bachelor's
# Analytics region_23 m referred Bachelor's
# Analytics region_8 m sourcing Bachelor's
# Analytics region_8 m other Bachelor's
# Analytics region_14 m sourcing Bachelor's
# Analytics region_14 m other Bachelor's
# Analytics region_31 m sourcing Bachelor's
# Analytics region_31 m other Bachelor's
# Analytics region_31 m referred Bachelor's
# Analytics region_31 f sourcing Bachelor's
# Analytics region_31 f other Bachelor's
# Analytics region_19 m sourcing Bachelor's
# Analytics region_19 m other Bachelor's
# Analytics region_5 m sourcing Bachelor's
# Analytics region_5 m other Bachelor's
# Analytics region_5 m referred Master's & above
# Analytics region_28 m sourcing Bachelor's
# Analytics region_28 m other Master's & above
# Analytics region_28 m referred Master's & above
# Analytics region_28 f sourcing Master's & above
# Analytics region_28 f other Bachelor's
# Analytics region_15 m sourcing Bachelor's
# Analytics region_15 m other Bachelor's
# Analytics region_15 m referred Bachelor's
# Analytics region_15 f sourcing Bachelor's
# Analytics region_15 f other Bachelor's
# Analytics region_3 m sourcing Bachelor's
# Analytics region_3 m other Bachelor's
# Analytics region_3 m referred Bachelor's
# Analytics region_25 m sourcing Master's & above
# Analytics region_25 m other Bachelor's
# Analytics region_25 f sourcing Bachelor's
# Analytics region_25 f other Bachelor's
# Analytics region_12 m sourcing Bachelor's
# Analytics region_12 m other Bachelor's
# Analytics region_21 m sourcing Bachelor's
# Analytics region_21 m other Bachelor's
# Analytics region_21 m referred Bachelor's
# Analytics region_21 f sourcing Bachelor's
# Analytics region_21 f other Bachelor's
# Analytics region_30 m sourcing Bachelor's
# Analytics region_30 m other Bachelor's
# Analytics region_10 m sourcing Bachelor's
# Analytics region_10 m other Master's & above
# Analytics region_32 m sourcing Bachelor's
# Analytics region_32 m other Bachelor's
# Analytics region_32 f sourcing Bachelor's
# Analytics region_32 f other Bachelor's
# Analytics region_6 m sourcing Bachelor's
# Analytics region_6 m other Bachelor's
# Analytics region_6 m referred Bachelor's
# Analytics region_6 f sourcing Bachelor's
# Analytics region_6 f other Bachelor's
# Analytics region_1 m sourcing Master's & above
# Analytics region_1 m other Master's & above
# Operations region_26 m sourcing Bachelor's
# Operations region_26 m other Bachelor's
# Operations region_26 m referred Bachelor's
# Operations region_26 f sourcing Bachelor's
# Operations region_26 f other Bachelor's
# Operations region_4 m sourcing Bachelor's
# Operations region_4 m other Bachelor's
# Operations region_4 m referred Bachelor's
# Operations region_4 f sourcing Bachelor's
# Operations region_4 f other Master's & above
# Operations region_4 f referred Master's & above
# Operations region_13 m sourcing Bachelor's
# Operations region_13 m other Bachelor's
# Operations region_13 m referred Master's & above
# Operations region_13 f sourcing Bachelor's
# Operations region_13 f other Bachelor's
# Operations region_13 f referred Master's & above
# Operations region_2 m sourcing Bachelor's
# Operations region_2 m other Bachelor's
# Operations region_2 m referred Master's & above
# Operations region_2 f sourcing Bachelor's
# Operations region_2 f other Bachelor's
# Operations region_2 f referred Bachelor's
# R&D region_19 m other Bachelor's
# R&D region_5 m other Bachelor's
# R&D region_28 m sourcing Master's & above
# R&D region_28 m other Master's & above
# R&D region_15 m sourcing Master's & above
# R&D region_15 m other Bachelor's
# R&D region_3 m sourcing Master's & above
# R&D region_3 m other Master's & above
# R&D region_25 m sourcing Master's & above
# R&D region_25 m other Bachelor's
# R&D region_30 m sourcing Master's & above
# R&D region_30 m other Bachelor's
# R&D region_30 f other Master's & above
# R&D region_10 m sourcing Bachelor's
# R&D region_10 m other Master's & above
# R&D region_32 m sourcing Bachelor's
# R&D region_32 m other Bachelor's
# R&D region_6 m other Bachelor's

# %%
test.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education                  1
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %% [markdown]
# Impute previous_year_rating:
#     1. no_of_trainings
#     2. is_promoted
#     3. KPIs_met >80%
#     4. awards_won
#     5. department
#     6. region
#     7. education
#     8. gender

# %%
from math import floor

for pro in train['is_promoted'].unique():
    for tr in train['no_of_trainings'].unique():
        for kpi in train['KPIs_met >80%'].unique(): 
            for awards in train['awards_won'].unique():

                try:    
                    df_slice = train[train['is_promoted']==pro][train['no_of_trainings']==tr][train['KPIs_met >80%']==kpi][train['awards_won']==awards]

                    null_indexes = list(df_slice[df_slice['previous_year_rating'].isna()==True].index)
                    median_value = df_slice[df_slice['previous_year_rating'].isna()==False]['previous_year_rating'].median()

                    print (pro, tr, kpi, awards, median_value)

                    for i in null_indexes:
                        train['previous_year_rating'].iloc[i] = floor(median_value)
                except:
                    pass
                
#for pro in test['is_promoted'].unique():
for tr in test['no_of_trainings'].unique():
    for kpi in test['KPIs_met >80%'].unique(): 
        for awards in test['awards_won?'].unique():

            try:    
                df_slice = test[test['no_of_trainings']==tr][test['KPIs_met >80%']==kpi][test['awards_won?']==awards]

                null_indexes = list(df_slice[df_slice['previous_year_rating'].isna()==True].index)
                median_value = df_slice[df_slice['previous_year_rating'].isna()==False]['previous_year_rating'].median()

                print (tr, kpi, awards, median_value)

                for i in null_indexes:
                    test['previous_year_rating'].iloc[i] = floor(median_value)
            except:
                pass
# Out:
# 0 1 1 0 4.0
# 0 1 1 1 3.0
# 0 1 0 0 3.0
# 0 1 0 1 3.0
# 0 2 1 0 4.0
# 0 2 1 1 3.0
# 0 2 0 0 3.0
# 0 2 0 1 3.0
# 0 3 1 0 4.0
# 0 3 1 1 3.0
# 0 3 0 0 3.0
# 0 3 0 1 3.0
# 0 4 1 0 3.0
# 0 4 1 1 5.0
# 0 4 0 0 3.0
# 0 4 0 1 1.0
# 0 7 1 0 3.5
# 0 7 1 1 nan
# 0 7 0 0 3.0
# 0 7 0 1 nan
# 0 5 1 0 4.0
# 0 5 1 1 nan
# 0 5 0 0 3.0
# 0 5 0 1 1.0
# 0 6 1 0 4.0
# 0 6 1 1 nan
# 0 6 0 0 3.0
# 0 6 0 1 3.0
# 0 8 1 0 3.5
# 0 8 1 1 nan
# 0 8 0 0 2.0
# 0 8 0 1 nan
# 0 10 1 0 nan
# 0 10 1 1 nan
# 0 10 0 0 3.0
# 0 10 0 1 nan
# 0 9 1 0 nan
# 0 9 1 1 nan
# 0 9 0 0 3.0
# 0 9 0 1 nan
# 1 1 1 0 4.0
# 1 1 1 1 4.0
# 1 1 0 0 4.0
# 1 1 0 1 4.0
# 1 2 1 0 4.0
# 1 2 1 1 3.0
# 1 2 0 0 5.0
# 1 2 0 1 3.5
# 1 3 1 0 4.0
# 1 3 1 1 4.0
# 1 3 0 0 4.5
# 1 3 0 1 5.0
# 1 4 1 0 4.0
# 1 4 1 1 4.0
# 1 4 0 0 5.0
# 1 4 0 1 nan
# 1 7 1 0 nan
# 1 7 1 1 nan
# 1 7 0 0 nan
# 1 7 0 1 nan
# 1 5 1 0 5.0
# 1 5 1 1 nan
# 1 5 0 0 nan
# 1 5 0 1 nan
# 1 6 1 0 1.0
# 1 6 1 1 nan
# 1 6 0 0 nan
# 1 6 0 1 nan
# 1 8 1 0 nan
# 1 8 1 1 nan
# 1 8 0 0 nan
# 1 8 0 1 nan
# 1 10 1 0 nan
# 1 10 1 1 nan
# 1 10 0 0 nan
# 1 10 0 1 nan
# 1 9 1 0 nan
# 1 9 1 1 nan
# 1 9 0 0 nan
# 1 9 0 1 nan
# 1 1 0 4.0
# 1 1 1 4.0
# 1 0 0 3.0
# 1 0 1 3.0
# 3 1 0 4.0
# 3 1 1 3.0
# 3 0 0 3.0
# 3 0 1 3.5
# 2 1 0 4.0
# 2 1 1 3.0
# 2 0 0 3.0
# 2 0 1 4.0
# 4 1 0 4.0
# 4 1 1 2.0
# 4 0 0 3.0
# 4 0 1 3.0
# 5 1 0 3.5
# 5 1 1 3.5
# 5 0 0 3.0
# 5 0 1 nan
# 7 1 0 4.0
# 7 1 1 nan
# 7 0 0 3.0
# 7 0 1 nan
# 6 1 0 5.0
# 6 1 1 nan
# 6 0 0 3.0
# 6 0 1 nan
# 8 1 0 4.0
# 8 1 1 nan
# 8 0 0 5.0
# 8 0 1 nan
# 9 1 0 4.0
# 9 1 1 nan
# 9 0 0 3.0
# 9 0 1 nan

# %%
'''
test.columns = ['employee_id', 'department', 'region', 'education', 'gender',
       'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
       'length_of_service', 'KPIs_met >80%', 'awards_won',
       'avg_training_score']
'''
# Out:
# "\ntest.columns = ['employee_id', 'department', 'region', 'education', 'gender',\n       'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',\n       'length_of_service', 'KPIs_met >80%', 'awards_won',\n       'avg_training_score']\n"

# %%
test.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score'],
#       dtype='object')

# %%
test = test.rename(columns={'awards_won?': 'awards_won'})

# %%
train['previous_year_rating'] = train['previous_year_rating'].fillna(0)
test['previous_year_rating'] = test['previous_year_rating'].fillna(0)



print (train.isnull().sum())
print (test.isnull().sum())
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won              0
# avg_training_score      0
# dtype: int64

# %%
#feature engineering

def feature_engineering(df):
    train = df
    
    train['joining_age'] = train['age']-train['length_of_service']
    train['total_training_time'] = train['no_of_trainings']*train['avg_training_score']


    ### New feature-number of training hours
    train['Number_of_training_hours']=train['no_of_trainings']*train['avg_training_score']
    ### Education importance
    train['Education Importance']  =1
    train['Education Importance'][train['education'] == "Master's & above"] = 3

    train['Education Importance'][train['education'] == "Bachelor's" ] = 2

    train['Education Importance'][train['education'] == 'Below Secondary' ] = 1

    ### train['Education Importance'].unique()
    train['Imp_KPI'] = train['previous_year_rating'] + train['KPIs_met >80%'] + train['awards_won']

    ### age bucketing

    bins = [20, 26, 30, 36, 40, 46, 60]
    labels = ['20-25', '26-39', '30-35', '36-39', '40-45', '46+']
    # train['agerange'] = pd.cut(train.age, bins, labels = labels,include_lowest = True)


    # second degree polynomial features
    train['department|training'] = train['department'] + np.digitize(train['avg_training_score'], [c * 10 for c in range(3, 11)]).astype(str)
    train['kpi|training'] = train['KPIs_met >80%'].astype(str) + np.digitize(train['avg_training_score'], [c * 10 for c in range(3, 11)]).astype(str)
    train['department|kpi'] = train['department'] + train['KPIs_met >80%'].astype(str)
    train['kpi*rating'] = train['KPIs_met >80%'] * train['previous_year_rating']

    train['mean_training_by_department'] = train['department'].map(train.groupby('department')['avg_training_score'].mean())
    train['department_training_mean_ratio'] = train['avg_training_score'] / train['mean_training_by_department']

    train['mean_rating_by_department'] = train['department'].map(train.groupby('department')['previous_year_rating'].mean())
    train['department_rating_mean_ratio'] = train['previous_year_rating'] / train['mean_rating_by_department']

    train['mean_kpi_by_department'] = train['department'].map(train.groupby('department')['KPIs_met >80%'].mean())
    
    # It has been observed that employees between the age 27,41 are more likely to get promoted
    train['age_flag'] = train['age'].between(27,41)*1
    
    return train

# %%
train = feature_engineering(train)
test = feature_engineering(test)

# %%
# train.corr()['is_promoted']

# %%
train.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  ...  department|training  kpi|training  \
# 0                  8  ...   Sales & Marketing2            12
# 1                  4  ...          Operations4            04
# 2                  7  ...   Sales & Marketing3            03
# 3                 10  ...   Sales & Marketing3            03
# 4                  2  ...          Technology5            05
#
#        department|kpi  kpi*rating  mean_training_by_department  \
# 0  Sales & Marketing1         5.0                    50.261698
# 1         Operations0         0.0                    60.226648
# 2  Sales & Marketing0         0.0                    50.261698
# 3  Sales & Marketing0         0.0                    50.261698
# 4         Technology0         0.0                    79.928692
#
#    department_training_mean_ratio  mean_rating_by_department  \
# 0                        0.974897                   2.829097
# 1                        0.996237                   3.443955
# 2                        0.994793                   2.829097
# 3                        0.994793                   2.829097
# 4                        0.913314                   2.917064
#
#    department_rating_mean_ratio  mean_kpi_by_department age_flag
# 0                      1.767348                0.265083        1
# 1                      1.451819                0.430737        1
# 2                      1.060409                0.265083        1
# 3                      0.353470                0.265083        1
# 4                      1.028431                0.344354        0
#
# [5 rows x 29 columns]

# %%
def extract_region(region):
    return int(region.split('_')[-1])

# %%
from multiprocessing.dummy import Pool as ThreadPool 
pool = ThreadPool(4) 

train['region'] = pool.map(extract_region, train['region'])
test['region'] = pool.map(extract_region, test['region'])
test.head()
# Out:
#    employee_id         department  region   education gender  \
# 0         8724         Technology      26  Bachelor's      m
# 1        74430                 HR       4  Bachelor's      f
# 2        72255  Sales & Marketing      13  Bachelor's      m
# 3        38562        Procurement       2  Bachelor's      f
# 4        64486            Finance      29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   0.0
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  ...  department|training  kpi|training  \
# 0                  1  ...          Technology5            15
# 1                  5  ...                  HR3            03
# 2                  4  ...   Sales & Marketing2            02
# 3                  9  ...         Procurement4            04
# 4                  7  ...             Finance4            04
#
#        department|kpi  kpi*rating  mean_training_by_department  \
# 0         Technology1         0.0                    79.860511
# 1                 HR0         0.0                    50.305991
# 2  Sales & Marketing0         0.0                    50.085988
# 3        Procurement0         0.0                    70.146026
# 4            Finance0         0.0                    60.322640
#
#    department_training_mean_ratio  mean_rating_by_department  \
# 0                        0.964181                   2.895384
# 1                        1.013796                   3.195392
# 2                        0.938386                   2.835270
# 3                        0.926638                   3.070199
# 4                        1.011229                   3.202566
#
#    department_rating_mean_ratio mean_kpi_by_department age_flag
# 0                      0.000000               0.350714        0
# 1                      0.938852               0.349309        1
# 2                      0.352700               0.276418        1
# 3                      0.651424               0.377483        1
# 4                      1.248998               0.396884        1
#
# [5 rows x 28 columns]

# %%
# test['education'] = test['education'].fillna(test['education'].mode())

# %%
df_encode = pd.concat([train, test])
df_encode.head()
# Out:
#    Education Importance  Imp_KPI  KPIs_met >80%  Number_of_training_hours  \
# 0                     3      6.0              1                        49
# 1                     2      5.0              0                        60
# 2                     2      3.0              0                        50
# 3                     2      1.0              0                       100
# 4                     2      3.0              0                        73
#
#    age  age_flag  avg_training_score  awards_won         department  \
# 0   35         1                  49           0  Sales & Marketing
# 1   30         1                  60           0         Operations
# 2   34         1                  50           0  Sales & Marketing
# 3   39         1                  50           0  Sales & Marketing
# 4   45         0                  73           0         Technology
#
#    department_rating_mean_ratio  ...  kpi|training length_of_service  \
# 0                      1.767348  ...            12                 8
# 1                      1.451819  ...            04                 4
# 2                      1.060409  ...            03                 7
# 3                      0.353470  ...            03                10
# 4                      1.028431  ...            05                 2
#
#   mean_kpi_by_department mean_rating_by_department  \
# 0               0.265083                  2.829097
# 1               0.430737                  3.443955
# 2               0.265083                  2.829097
# 3               0.265083                  2.829097
# 4               0.344354                  2.917064
#
#    mean_training_by_department no_of_trainings  previous_year_rating  \
# 0                    50.261698               1                   5.0
# 1                    60.226648               1                   5.0
# 2                    50.261698               1                   3.0
# 3                    50.261698               2                   1.0
# 4                    79.928692               1                   3.0
#
#    recruitment_channel  region total_training_time
# 0             sourcing       7                  49
# 1                other      22                  60
# 2             sourcing      19                  50
# 3                other      23                 100
# 4                other      26                  73
#
# [5 rows x 29 columns]

# %%
from sklearn.preprocessing import LabelEncoder

str_columns = ['department', 'education', 'gender', 'recruitment_channel', 'department|training',
               'department|kpi']


for c in str_columns:
    print (c)
    le = LabelEncoder()
    encoded = le.fit_transform(df_encode[c])
    df_encode[c] = encoded
# Out:
# department
# education
# gender
# recruitment_channel
# department|training
# department|kpi

# %%
df_encode.head()
# Out:
#    Education Importance  Imp_KPI  KPIs_met >80%  Number_of_training_hours  \
# 0                     3      6.0              1                        49
# 1                     2      5.0              0                        60
# 2                     2      3.0              0                        50
# 3                     2      1.0              0                       100
# 4                     2      3.0              0                        73
#
#    age  age_flag  avg_training_score  awards_won  department  \
# 0   35         1                  49           0           7
# 1   30         1                  60           0           4
# 2   34         1                  50           0           7
# 3   39         1                  50           0           7
# 4   45         0                  73           0           8
#
#    department_rating_mean_ratio  ...  kpi|training  length_of_service  \
# 0                      1.767348  ...            12                  8
# 1                      1.451819  ...            04                  4
# 2                      1.060409  ...            03                  7
# 3                      0.353470  ...            03                 10
# 4                      1.028431  ...            05                  2
#
#    mean_kpi_by_department  mean_rating_by_department  \
# 0                0.265083                   2.829097
# 1                0.430737                   3.443955
# 2                0.265083                   2.829097
# 3                0.265083                   2.829097
# 4                0.344354                   2.917064
#
#    mean_training_by_department  no_of_trainings  previous_year_rating  \
# 0                    50.261698                1                   5.0
# 1                    60.226648                1                   5.0
# 2                    50.261698                1                   3.0
# 3                    50.261698                2                   1.0
# 4                    79.928692                1                   3.0
#
#    recruitment_channel  region total_training_time
# 0                    2       7                  49
# 1                    0      22                  60
# 2                    2      19                  50
# 3                    0      23                 100
# 4                    0      26                  73
#
# [5 rows x 29 columns]

# %%
train = df_encode[df_encode['is_promoted'].isna()==False]
test = df_encode[df_encode['is_promoted'].isna()==True]
train.shape, test.shape
# Out:
# ((54808, 29), (23490, 29))

# %%
# convert all columns of DataFrame


#train = train.drop(columns=['agerange'])
#test = test.drop(columns=['agerange'])

train = train.apply(pd.to_numeric) # convert all columns of DataFrame
test = test.apply(pd.to_numeric) # convert all columns of DataFrame

train.shape, test.shape
# Out:
# ((54808, 29), (23490, 29))

# %%
train.columns
# Out:
# Index(['Education Importance', 'Imp_KPI', 'KPIs_met >80%',
#        'Number_of_training_hours', 'age', 'age_flag', 'avg_training_score',
#        'awards_won', 'department', 'department_rating_mean_ratio',
#        'department_training_mean_ratio', 'department|kpi',
#        'department|training', 'education', 'employee_id', 'gender',
#        'is_promoted', 'joining_age', 'kpi*rating', 'kpi|training',
#        'length_of_service', 'mean_kpi_by_department',
#        'mean_rating_by_department', 'mean_training_by_department',
#        'no_of_trainings', 'previous_year_rating', 'recruitment_channel',
#        'region', 'total_training_time'],
#       dtype='object')

# %%
# train['kpi|training'] #kpi|training, region

# %%
train_x = train[['Education Importance', 'Imp_KPI', 'KPIs_met >80%',
       'Number_of_training_hours', 'age', 'age_flag', 'avg_training_score',
       'awards_won', 'department', 'department_rating_mean_ratio',
       'department_training_mean_ratio', 'department|kpi',
       'department|training', 'education', 'employee_id', 'gender',
       'is_promoted', 'joining_age', 'kpi*rating', 'kpi|training',
       'length_of_service', 'mean_kpi_by_department',
       'mean_rating_by_department', 'mean_training_by_department',
       'no_of_trainings', 'previous_year_rating', 'recruitment_channel',
       'region', 'total_training_time']]

# %%
train_y=train[['is_promoted']]
train_x=train.drop(columns=['is_promoted'])

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.1, random_state=42,stratify=train_y)

# %%
X_train.head()
# Out:
#        Education Importance  Imp_KPI  KPIs_met >80%  Number_of_training_hours  \
# 15160                     2      5.0              1                        48
# 54112                     2      5.0              1                        58
# 51855                     2      5.0              1                       162
# 8196                      2      6.0              1                        49
# 5313                      2      5.0              1                        82
#
#        age  age_flag  avg_training_score  awards_won  department  \
# 15160   25         0                  48           0           2
# 54112   56         0                  58           0           4
# 51855   28         1                  81           0           0
# 8196    41         1                  49           0           7
# 5313    32         1                  82           0           0
#
#        department_rating_mean_ratio  ...  kpi|training  length_of_service  \
# 15160                      1.278519  ...            12                  1
# 54112                      1.161455  ...            13                 10
# 51855                      1.231690  ...            16                  6
# 8196                       1.767348  ...            12                 15
# 5313                       1.231690  ...            16                  6
#
#        mean_kpi_by_department  mean_rating_by_department  \
# 15160                0.334160                   3.128619
# 54112                0.430737                   3.443955
# 51855                0.404148                   3.247571
# 8196                 0.265083                   2.829097
# 5313                 0.404148                   3.247571
#
#        mean_training_by_department  no_of_trainings  previous_year_rating  \
# 15160                    50.018197                1                   4.0
# 54112                    60.226648                1                   4.0
# 51855                    84.602952                2                   4.0
# 8196                     50.261698                1                   5.0
# 5313                     84.602952                1                   4.0
#
#        recruitment_channel  region  total_training_time
# 15160                    0       2                   48
# 54112                    0       2                   58
# 51855                    2      22                  162
# 8196                     0       4                   49
# 5313                     2      29                   82
#
# [5 rows x 28 columns]

# %%
X_train.drop(columns=['employee_id'],inplace= True)
X_test.drop(columns=['employee_id'],inplace= True)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((49327, 27), (5481, 27), (49327, 1), (5481, 1))

# %%
from xgboost import XGBClassifier

# %%
modelXg = XGBClassifier(base_score=0.37, learning_rate=0.1, n_estimators=100, max_depth=4, min_child_weight=7, 
                      gamma=0.4,nthread=4, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic',scale_pos_weight=3,seed=29)
modelXg.fit(X_train, y_train)
y_xg = modelXg.predict(X_test)

# %%
# modelXg.score(X_test, y_test), 
modelXg.score(X_test, y_test)
# Out:
# 0.9345010034665208

# %%
from sklearn.metrics import confusion_matrix ,f1_score as f1
f1(y_train,modelXg.predict(X_train))
# Out:
# 0.5486935866983373

# %%
confusion_matrix(y_train,modelXg.predict(X_train))
# Out:
# array([[44439,   687],
#        [ 2353,  1848]], dtype=int64)

# %%
dict(zip(X_train.columns, modelXg.feature_importances_))
# Out:
# {'Education Importance': 0.010414928,
#  'Imp_KPI': 0.03160037,
#  'KPIs_met >80%': 0.19593194,
#  'Number_of_training_hours': 0.012338435,
#  'age': 0.00889895,
#  'age_flag': 0.003012636,
#  'avg_training_score': 0.034296732,
#  'awards_won': 0.046427175,
#  'department': 0.019508805,
#  'department_rating_mean_ratio': 0.020178411,
#  'department_training_mean_ratio': 0.17080186,
#  'department|kpi': 0.01641809,
#  'department|training': 0.033487823,
#  'education': 0.006391556,
#  'gender': 0.005177021,
#  'joining_age': 0.011433432,
#  'kpi*rating': 0.016606886,
#  'kpi|training': 0.25524446,
#  'length_of_service': 0.01089543,
#  'mean_kpi_by_department': 0.008907024,
#  'mean_rating_by_department': 0.015151387,
#  'mean_training_by_department': 0.021158766,
#  'no_of_trainings': 0.0,
#  'previous_year_rating': 0.023813352,
#  'recruitment_channel': 0.0045483112,
#  'region': 0.009814166,
#  'total_training_time': 0.007542015}

# %%
X_train.education.unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %%
train[train.education==0]['is_promoted'].value_counts()
# Out:
# 0.0    33661
# 1.0     3008
# Name: is_promoted, dtype: int64

# %%
X_train['previous_year_rating'].unique()
# Out:
# array([4., 5., 0., 1., 2., 3.])

# %%
(X_train.columns)
# Out:
# Index(['Education Importance', 'Imp_KPI', 'KPIs_met >80%',
#        'Number_of_training_hours', 'age', 'age_flag', 'avg_training_score',
#        'awards_won', 'department', 'department_rating_mean_ratio',
#        'department_training_mean_ratio', 'department|kpi',
#        'department|training', 'education', 'gender', 'joining_age',
#        'kpi*rating', 'kpi|training', 'length_of_service',
#        'mean_kpi_by_department', 'mean_rating_by_department',
#        'mean_training_by_department', 'no_of_trainings',
#        'previous_year_rating', 'recruitment_channel', 'region',
#        'total_training_time'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Education Importance', 'Imp_KPI', 'KPIs_met >80%',
#        'Number_of_training_hours', 'age', 'age_flag', 'avg_training_score',
#        'awards_won', 'department', 'department_rating_mean_ratio',
#        'department_training_mean_ratio', 'department|kpi',
#        'department|training', 'education', 'employee_id', 'gender',
#        'is_promoted', 'joining_age', 'kpi*rating', 'kpi|training',
#        'length_of_service', 'mean_kpi_by_department',
#        'mean_rating_by_department', 'mean_training_by_department',
#        'no_of_trainings', 'previous_year_rating', 'recruitment_channel',
#        'region', 'total_training_time'],
#       dtype='object')

# %%
#test = np.array(test)

# %%
Xg_test = modelXg.predict(test[X_train.columns])
# ada_test = modelXg.predict(test[X_train.columns])

# %%
Xg_test.astype(int)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
sub = pd.DataFrame({'employee_id':test.employee_id,'is_promoted':Xg_test.astype(int)})
sub.to_csv('submission_v7.csv',index=False)

# %%
XGBClassifier(learning_rate=0.1, n_estimators=100, max_depth=4, min_child_weight=7, 
                      gamma=0.4,nthread=4, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic',scale_pos_weight=3,seed=29)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.4,
#               learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=7, missing=None, n_estimators=100, n_jobs=1,
#               nthread=4, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=3, seed=29,
#               silent=None, subsample=0.8, verbosity=1)

# %%
df_proba = pd.DataFrame(modelXg.predict_proba(X_train))
df_proba['Target'] =  y_train
df_proba['Predicted'] = modelXg.predict(X_train)
df_proba.to_csv('probabilities_targts_1.csv', index=False)

# %%
from math import sqrt

scale_pos_weight = sqrt(train[train['is_promoted']==0].shape[0]/train[train['is_promoted']==1].shape[0])
scale_pos_weight
# Out:
# 3.2773795622724826

# %% [markdown]
# ### Grid Search Implementation

# %%
# gamma=0.4,nthread=4, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic',scale_pos_weight=3,seed=29)

# %%
from sklearn.model_selection import GridSearchCV

model= XGBClassifier()

# base_score=0.37, learning_rate=0.1, n_estimators=100, max_depth=4, min_child_weight=7, 

#Hyper Parameters Set
params = {'max_depth': [4],
          'base_score': [0.37],
          'learning_rate': [0.1],
          'n_estimators': [100],
          'min_child_weight': [7],
          'subsample': [0.8],
          'colsample_bytree': [0.8],
          'objective': ['binary:logistic', 'binary:logitraw', 'reg:logistic', 'binary:logitraw'
                        'binary:hinge'
                       ],
          #'scale_pos_weight': [3],
          'random_state':[123],
          'n_jobs': [-1],
          'booster': ['gbtree'],
          # 'max_bin': [256, 512, 128, 64]
         }

#Making models with hyper parameters sets
model1 = GridSearchCV(model, param_grid=params, n_jobs=-1)

# %%
model1.fit(X_train, y_train)

# %%
model1.best_params_

# %% [markdown]
# 1. #46 with
#   XGBClassifier(learning_rate=0.1, n_estimators=100, max_depth=4, min_child_weight=7,
#                       gamma=0.4,nthread=4, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic',scale_pos_weight=3,seed=29)

# %%
train.to_csv('train_feat_matrix.csv', index=False)
test.to_csv('test_feat_matrix.csv', index=False)

# %%
# test

# %% [markdown]
# ### Correlations

# %%
import seaborn as sns
import pandas as pd

data = train

plt.figure(figsize=(7,7)) 
# play with the figsize until the plot is big enough to plot all the columns
# of your dataset, or the way you desire it to look like otherwise

sns.heatmap(data.corr())

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

# %%
X_coll = calculate_vif_(X_train)

# %%
X_coll.columns.values

# %% [markdown]
# #### Gradient Boosting Implementation

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
modelXg = XGBClassifier(base_score=0.37, learning_rate=0.1, n_estimators=100, max_depth=4, min_child_weight=7, 
                      gamma=0.4,nthread=4, subsample=0.8, colsample_bytree=0.8, objective= 'binary:logistic',scale_pos_weight=3,seed=29)

# %%
gb_clf = GradientBoostingClassifier(learning_rate=0.07, n_estimators=110, max_depth=6, subsample=0.8)
gb_clf.fit(X_train, y_train)
gb_clf.score(X_train, y_train)

# %%
f1(y_test,gb_clf.predict(X_test))

# %%
confusion_matrix(y_test,gb_clf.predict(X_test))

# %%
gb_test = gb_clf.predict(test[X_train.columns])
sub = pd.DataFrame({'employee_id':test.employee_id,'is_promoted':gb_test.astype(int)})
sub.to_csv('submission_v7.csv',index=False)
